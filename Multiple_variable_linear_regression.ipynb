# %% [markdown]
# # Assignment2: Multiple variable Linear Regression
#
# ## Summary
# In this homework, you will learn how to use `pandas` and `sklean` to implement multiple variable linear regression with startup data.
#
# ## What you have to do
# - Copy this colab as `YOUR_ID.ipynb` to your google drive
# - Implement all `TODO` parts following the comment
# - Download `YOUR_ID.ipynb` and submit the file to YS LearnUS
#
# ## How to evalulate
# - We will evaluate your code with automatic test framework
# - **!!!!!IMPORTANT!!!!!** You need to keep other part for proper evaluation
#
# ## Reference
# - [Python documentation](https://docs.python.org/3/)
# - [scikit-learn documentation](https://scikit-learn.org/stable/index.html)
# - [pandas documentation](https://pandas.pydata.org/docs/)
# - Materials on [YS LearnUS](https://ys.learnus.org/)

# %% [markdown]
# ### Data Preparation
#
# You can download the '50_Startups.csv' from [Kaggle](https://www.kaggle.com/datasets/amineoumous/50-startups-data?resource=download).
# We also prepare [backup google drive link](https://drive.google.com/file/d/1Z2-RCPcDaz6XwiOhIiITGBHyCTUmMvo-/view?usp=sharing) for you.
#
# **Action Item**
# - [ ] Download data to your local machine
# - [ ] Execute code block to check you implement properly (This does not guarantee your HW score)

# %%
import pandas as pd

dataset = pd.read_csv('50_Startups.csv')
dataset.info()
dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# ...

# %% [markdown]
# ### Train and Test the model
#
# **Action Item**
# - [ ] Implement all `TODO` parts
# - [ ] Execute code block to check you implement properly (This does not guarantee your HW score)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


# Prepare dataset
X = dataset.drop(['Profit', 'State'], axis=1)
y = dataset['Profit']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=2023)

# TODO: Initialize LinearRegression with regressor

# TODO: Train regressor with `regressor.fit`, `X_train`, and `y_train`

# TODO: Predict the `X_test` with `regressor.predict` to predict `y_pred`


# Calculate the score for the test set
print(f"Score: {regressor.score(X_test, y_test)}")
# Visualize the prediction and corresponding groud truth
print(X_test.join(pd.DataFrame({'y_pred': y_pred, 'y_test': y_test})))
# Out:
# Score: 0.9234064133421133
#     R&D Spend  Administration  Marketing Spend         y_pred     y_test
# 34   46426.07       157693.92        210797.67   89322.413065   96712.80
# 35   46014.02        85047.44        205517.64   88300.679228   96479.51
# 9   123334.88       108679.17        304981.62  152723.971034  149759.96
# 2   153441.51       101145.55        407934.54  179755.036374  191050.39
# 21   78389.47       153773.43        299737.29  117394.551977  111313.02
# 12   93863.75       127320.38        249839.44  127814.397032  141585.52
# 38   20229.59        65947.93        185265.10   67151.770639   81229.06
# 10  101913.08       110594.11        229160.95  133382.938205  146121.95
# 42   23640.93        96189.63        148001.11   68864.692428   71498.49
# 19   86419.70       153514.11             0.00  114083.219187  122776.86
